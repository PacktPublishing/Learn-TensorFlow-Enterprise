# %%
import tensorflow as tf
import neural_structured_learning as nsl
import tensorflow_hub as hub
import tensorflow_datasets as tfds
import numpy as np
import os
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
import IPython.display as display
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
print(tf.__version__)
print(nsl.__version__)
# Out:
# 2.3.0
# 1.3.1

# %%
import sys
print(sys.executable)
# Out:
# /Users/mbp16/Documents/projects/tf23/bin/python3.8

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.5

# %%
root_dir = '../chapter_07/train_base_model/tf_datasets/flower_photos'
train_file_pattern = "{}/image_classification_builder-train*.tfrecord*".format(root_dir)
val_file_pattern = "{}/image_classification_builder-validation*.tfrecord*".format(root_dir)
test_file_pattern = "{}/image_classification_builder-test*.tfrecord*".format(root_dir)

# %%
train_all_files = tf.data.Dataset.list_files( tf.io.gfile.glob(train_file_pattern))
val_all_files = tf.data.Dataset.list_files( tf.io.gfile.glob(val_file_pattern))
test_all_files = tf.data.Dataset.list_files( tf.io.gfile.glob(test_file_pattern))

# %%
train_all_ds = tf.data.TFRecordDataset(train_all_files, num_parallel_reads = AUTOTUNE)
val_all_ds = tf.data.TFRecordDataset(val_all_files, num_parallel_reads = AUTOTUNE)
test_all_ds = tf.data.TFRecordDataset(test_all_files, num_parallel_reads = AUTOTUNE)

# %%
train_sample_size = sum(1 for _ in tf.data.TFRecordDataset(train_all_files))
validation_sample_size = sum(1 for _ in tf.data.TFRecordDataset(val_all_files))
test_sample_size = sum(1 for _ in tf.data.TFRecordDataset(test_all_files))

# %%
print("Sample size for training: {0}".format(train_sample_size)
     ,'\n', "Sample size for validation: {0}".format(validation_sample_size)
     ,'\n', "Sample size for test: {0}".format(test_sample_size))
# Out:
# Sample size for training: 3540
#  Sample size for validation: 80
#  Sample size for test: 50

# %% [markdown]
# ## Transforming TFRecords for training

# %%
def decode_and_resize(serialized_example):
    # resized image should be [224, 224, 3] and normalized to value range [0, 255] 
    # label is integer index of class.
    
    parsed_features = tf.io.parse_single_example(
      serialized_example,
      features = {
    'image/channels' :  tf.io.FixedLenFeature([], tf.int64),
    'image/class/label' :  tf.io.FixedLenFeature([], tf.int64),
    'image/class/text' : tf.io.FixedLenFeature([], tf.string),
    'image/colorspace' : tf.io.FixedLenFeature([], tf.string),
    'image/encoded' : tf.io.FixedLenFeature([], tf.string),
    'image/filename' : tf.io.FixedLenFeature([], tf.string),
    'image/format' : tf.io.FixedLenFeature([], tf.string),
    'image/height' : tf.io.FixedLenFeature([], tf.int64),
    'image/width' : tf.io.FixedLenFeature([], tf.int64)
    })
    image = tf.io.decode_jpeg(parsed_features['image/encoded'], channels=3)
    label = tf.cast(parsed_features['image/class/label'], tf.int32)
    label_txt = tf.cast(parsed_features['image/class/text'], tf.string)
    label_one_hot = tf.one_hot(label, depth = 5)
    resized_image = tf.image.resize(image, [224, 224], method='nearest')
    return resized_image, label_one_hot

def normalize(image, label):
    #Convert `image` from [0, 255] -> [0, 1.0] floats 
    image = tf.cast(image, tf.float32) / 255.
    return image, label

# %%
resized_train_ds = train_all_ds.map(decode_and_resize, num_parallel_calls=AUTOTUNE)
resized_val_ds = val_all_ds.map(decode_and_resize, num_parallel_calls=AUTOTUNE)
resized_test_ds = test_all_ds.map(decode_and_resize, num_parallel_calls=AUTOTUNE)

resized_normalized_train_ds = resized_train_ds.map(normalize, num_parallel_calls=AUTOTUNE)
resized_normalized_val_ds = resized_val_ds.map(normalize, num_parallel_calls=AUTOTUNE)
resized_normalized_test_ds = resized_test_ds.map(normalize, num_parallel_calls=AUTOTUNE)

# %%
pixels =224
IMAGE_SIZE = (pixels, pixels)
TRAIN_BATCH_SIZE = 32
VAL_BATCH_SIZE = validation_sample_size
TEST_BATCH_SIZE = test_sample_size

# %%
NUM_EPOCHS = 5
SHUFFLE_BUFFER_SIZE = 1000

#prepped_test_ds = prepare_for_model(resized_normalized_test_ds, TEST_BATCH_SIZE, False, False)

prepped_test_ds = resized_normalized_test_ds.batch(TEST_BATCH_SIZE).prefetch(buffer_size = AUTOTUNE)

prepped_train_ds = resized_normalized_train_ds.repeat(100).shuffle(buffer_size=SHUFFLE_BUFFER_SIZE)
prepped_train_ds = prepped_train_ds.batch(TRAIN_BATCH_SIZE)
prepped_train_ds = prepped_train_ds.prefetch(buffer_size = AUTOTUNE)

prepped_val_ds = resized_normalized_val_ds.repeat(NUM_EPOCHS).shuffle(buffer_size=SHUFFLE_BUFFER_SIZE)
prepped_val_ds = prepped_val_ds.batch(80)
prepped_val_ds = prepped_val_ds.prefetch(buffer_size = AUTOTUNE)

# %%
train_image_batch, train_label_batch = next(iter(prepped_train_ds))
val_image_batch, val_label_batch = next(iter(prepped_val_ds))
test_image_batch, test_label_batch = next(iter(prepped_test_ds))

# %% [markdown]
# Now all training image batch should be [N, 224, 224, 3], all label batch should be [N, 5]

# %%
feature_description = {
    'image/channels' :  tf.io.FixedLenFeature([], tf.int64),
    'image/class/label' :  tf.io.FixedLenFeature([], tf.int64),
    'image/class/text' : tf.io.FixedLenFeature([], tf.string),
    'image/colorspace' : tf.io.FixedLenFeature([], tf.string),
    'image/encoded' : tf.io.FixedLenFeature([], tf.string),
    'image/filename' : tf.io.FixedLenFeature([], tf.string),
    'image/format' : tf.io.FixedLenFeature([], tf.string),
    'image/height' : tf.io.FixedLenFeature([], tf.int64),
    'image/width' : tf.io.FixedLenFeature([], tf.int64)
}


def _parse_function(example_proto):
  # Parse the input `tf.Example` proto using the dictionary above.
  return tf.io.parse_single_example(example_proto, feature_description)

parsd_ds = train_all_ds.map(_parse_function)

label_map = {}
# getting label mapping
for image_features in parsd_ds.shuffle(1024).take(100):
    label_idx = image_features['image/class/label'].numpy()
    label_str = image_features['image/class/text'].numpy().decode()
    if label_idx not in label_map:
        label_map[label_idx] = label_str

# %%
label_map
# Out:
# {4: 'tulips', 1: 'sunflowers', 3: 'dandelion', 0: 'roses', 2: 'daisy'}

# %%
FINE_TUNING_CHOICE = False
NUM_CLASSES = 5

# %%
os.environ["TFHUB_CACHE_DIR"] = '../chapter_07/imagenet_resnet_v2_50_feature_vector_4'

mdl = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
    hub.KerasLayer("https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4",
                   trainable=FINE_TUNING_CHOICE), 
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax', name = 'custom_class')
])
mdl.build([None, 224, 224, 3])

# %%
mdl.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 2048)              23564800
# _________________________________________________________________
# custom_class (Dense)         (None, 5)                 10245
# =================================================================
# Total params: 23,575,045
# Trainable params: 10,245
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
mdl.compile(
  optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_loss` score has improved.
        # The saved model name will include the current epoch.
        filepath="mymodel_{epoch}",
        save_best_only=False,  # Only save a model if `val_loss` has improved.
        monitor="val_accuracy",
        verbose=1,
    )
]

# %%
prepped_train_ds
# Out:
# <PrefetchDataset shapes: ((None, 224, 224, 3), (None, 5)), types: (tf.float32, tf.float32)>

# %% [markdown]
# `prepped_train_ds` is a tuple.

# %%
mdl.fit(
    prepped_train_ds,
    epochs=5, steps_per_epoch=100,
    validation_data=prepped_val_ds,
    validation_steps=1,
    callbacks=callbacks)
# Out:
# Epoch 1/5
# 100/100 [==============================] - ETA: 0s - loss: 1.2647 - accuracy: 0.6969
# Epoch 00001: saving model to mymodel_1
# WARNING:tensorflow:From /Users/mbp16/Documents/projects/tf23/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/mbp16/Documents/projects/tf23/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/mbp16/Documents/projects/tf23/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/mbp16/Documents/projects/tf23/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: mymodel_1/assets
# INFO:tensorflow:Assets written to: mymodel_1/assets
# 100/100 [==============================] - 92s 920ms/step - loss: 1.2647 - accuracy: 0.6969 - val_loss: 1.1303 - val_accuracy: 0.8500
# Epoch 2/5
# 100/100 [==============================] - ETA: 0s - loss: 1.1386 - accuracy: 0.8391
# Epoch 00002: saving model to mymodel_2
# INFO:tensorflow:Assets written to: mymodel_2/assets
# INFO:tensorflow:Assets written to: mymodel_2/assets
# 100/100 [==============================] - 94s 944ms/step - loss: 1.1386 - accuracy: 0.8391 - val_loss: 1.1129 - val_accuracy: 0.8750
# Epoch 3/5
# 100/100 [==============================] - ETA: 0s - loss: 1.1057 - accuracy: 0.8825
# Epoch 00003: saving model to mymodel_3
# INFO:tensorflow:Assets written to: mymodel_3/assets
# INFO:tensorflow:Assets written to: mymodel_3/assets
# 100/100 [==============================] - 94s 944ms/step - loss: 1.1057 - accuracy: 0.8825 - val_loss: 1.1124 - val_accuracy: 0.8875
# Epoch 4/5
# 100/100 [==============================] - ETA: 0s - loss: 1.0943 - accuracy: 0.9009
# Epoch 00004: saving model to mymodel_4
# INFO:tensorflow:Assets written to: mymodel_4/assets
# INFO:tensorflow:Assets written to: mymodel_4/assets
# 100/100 [==============================] - 94s 943ms/step - loss: 1.0943 - accuracy: 0.9009 - val_loss: 1.1126 - val_accuracy: 0.9000
# Epoch 5/5
# 100/100 [==============================] - ETA: 0s - loss: 1.0863 - accuracy: 0.9075
# Epoch 00005: saving model to mymodel_5
# INFO:tensorflow:Assets written to: mymodel_5/assets
# INFO:tensorflow:Assets written to: mymodel_5/assets
# 100/100 [==============================] - 95s 948ms/step - loss: 1.0863 - accuracy: 0.9075 - val_loss: 1.0884 - val_accuracy: 0.8875

# %% [markdown]
# ## Adversarial Regularization
#
# There is a requirement for adversarial regularization. This requirement is to combine the training data and label as a dictionary and then stream the dictionary into the training process. In earlier steps, we applied `decode_and_resize` and `normalize` ops to training, validation, and test dataset. After batching, these datasets are referenced by `prepped_train_ds`, `prepped_val_ds`, and `prepped_test_ds`, respectively.
#
# The approach is to create a function that creates the dictionary, and apply this cunction to each dataset. Here is the function `examples_to_dict` that forms and returns a dictionary based on input image and label:

# %%
def examples_to_dict(image, label):
  return {'image': image, 'label': label}

# %% [markdown]
# Now we may apply `examples_to_dict` to each element in our dataset using `map`.

# %%
train_set_for_adv_model = prepped_train_ds.map(examples_to_dict)
val_set_for_adv_model = prepped_val_ds.map(examples_to_dict)
test_set_for_adv_model = prepped_test_ds.map(examples_to_dict)

# %%
adv_config = nsl.configs.make_adv_reg_config()

# %%
adv_mdl = nsl.keras.AdversarialRegularization(mdl, label_keys=['label'],adv_config=adv_config)

# %%
adv_mdl.compile(optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
    metrics=['accuracy'])

# %% [markdown]
# Train the adversarial regularized model.

# %%
import time

# %%
tic = time.time()
adv_mdl.fit(
    train_set_for_adv_model,
    epochs=5, steps_per_epoch=100,
    validation_data=val_set_for_adv_model,
    validation_steps=1,
    callbacks=callbacks)
toc = time.time()
print('Total training time for adversrial regularized model in second: ', toc - tic)
# Out:
# Epoch 1/5
# 100/100 [==============================] - ETA: 0s - loss: 1.2912 - categorical_crossentropy: 1.0758 - categorical_accuracy: 0.9159 - scaled_adversarial_loss: 0.2153
# Epoch 00001: saving model to mymodel_1
# 100/100 [==============================] - 500s 5s/step - loss: 1.2912 - categorical_crossentropy: 1.0758 - categorical_accuracy: 0.9159 - scaled_adversarial_loss: 0.2153 - val_loss: 1.2722 - val_categorical_crossentropy: 1.0601 - val_categorical_accuracy: 0.9500 - val_scaled_adversarial_loss: 0.2121
# Epoch 2/5
# 100/100 [==============================] - ETA: 0s - loss: 1.2812 - categorical_crossentropy: 1.0676 - categorical_accuracy: 0.9272 - scaled_adversarial_loss: 0.2137
# Epoch 00002: saving model to mymodel_2
# 100/100 [==============================] - 478s 5s/step - loss: 1.2812 - categorical_crossentropy: 1.0676 - categorical_accuracy: 0.9272 - scaled_adversarial_loss: 0.2137 - val_loss: 1.2614 - val_categorical_crossentropy: 1.0511 - val_categorical_accuracy: 0.9500 - val_scaled_adversarial_loss: 0.2103
# Epoch 3/5
# 100/100 [==============================] - ETA: 0s - loss: 1.2744 - categorical_crossentropy: 1.0619 - categorical_accuracy: 0.9331 - scaled_adversarial_loss: 0.2125
# Epoch 00003: saving model to mymodel_3
# 100/100 [==============================] - 491s 5s/step - loss: 1.2744 - categorical_crossentropy: 1.0619 - categorical_accuracy: 0.9331 - scaled_adversarial_loss: 0.2125 - val_loss: 1.2790 - val_categorical_crossentropy: 1.0658 - val_categorical_accuracy: 0.9250 - val_scaled_adversarial_loss: 0.2132
# Epoch 4/5
# 100/100 [==============================] - ETA: 0s - loss: 1.2680 - categorical_crossentropy: 1.0566 - categorical_accuracy: 0.9388 - scaled_adversarial_loss: 0.2115
# Epoch 00004: saving model to mymodel_4
# 100/100 [==============================] - 465s 5s/step - loss: 1.2680 - categorical_crossentropy: 1.0566 - categorical_accuracy: 0.9388 - scaled_adversarial_loss: 0.2115 - val_loss: 1.3099 - val_categorical_crossentropy: 1.0915 - val_categorical_accuracy: 0.9000 - val_scaled_adversarial_loss: 0.2184
# Epoch 5/5
# 100/100 [==============================] - ETA: 0s - loss: 1.2638 - categorical_crossentropy: 1.0530 - categorical_accuracy: 0.9444 - scaled_adversarial_loss: 0.2107
# Epoch 00005: saving model to mymodel_5
# 100/100 [==============================] - 491s 5s/step - loss: 1.2638 - categorical_crossentropy: 1.0530 - categorical_accuracy: 0.9444 - scaled_adversarial_loss: 0.2107 - val_loss: 1.3256 - val_categorical_crossentropy: 1.1045 - val_categorical_accuracy: 0.9000 - val_scaled_adversarial_loss: 0.2211
# Total training time for adversrial regularized model in second:  2455.216376066208

# %%
reference_model = nsl.keras.AdversarialRegularization(
    mdl,
    label_keys=['label'],
    adv_config=adv_config)
reference_model.compile(
   optimizer=tf.keras.optimizers.SGD(lr=0.005, momentum=0.9), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1),
  metrics=['accuracy'])

# %%
models_to_eval = {
    'base': mdl,
    'adv-regularized': adv_mdl.base_model
}
metrics = {
    name: tf.keras.metrics.Accuracy()
    for name in models_to_eval.keys()
}

# %%
type(prepped_test_ds)
# Out:
# tensorflow.python.data.ops.dataset_ops.PrefetchDataset

# %% [markdown]
# Now we measure the accuracy of our base model `mdl` and adversarial regularized model `adv_mdl` on purturbed images:

# %%
from sklearn.metrics import accuracy_score

# %%
perturbed_images, labels, predictions = [], [], []

for batch in test_set_for_adv_model:
  perturbed_batch = reference_model.perturb_on_batch(batch)
  # Clipping makes perturbed examples have the same range as regular ones.
  perturbed_batch['image'] = tf.clip_by_value(                          
      perturbed_batch['image'], 0, 100)
  y_true = perturbed_batch.pop('label')
  true_idx = tf.argmax(y_true, axis=-1).numpy()
  perturbed_images.append(perturbed_batch['image'].numpy())
  labels.append(y_true.numpy())
  predictions.append({})
  for name, model in models_to_eval.items():
    y_pred = model(perturbed_batch)
    predictions[-1][name] = tf.argmax(y_pred, axis=-1).numpy()
    predicted_idx = tf.argmax(y_pred, axis=-1).numpy()
    #metrics[name](y_true, y_pred)
    print(name, accuracy_score(true_idx, predicted_idx))
# Out:
# base 0.86
# adv-regularized 0.86

# %%
batch_index = 0
batch_image = perturbed_images[batch_index]
batch_label = labels[batch_index]
batch_pred = predictions[batch_index]

batch_size = 50
n_col = 5
n_row = (batch_size + n_col - 1) / n_col

print('accuracy in batch %d:' % batch_index)
for name, pred in batch_pred.items():
  print('%s model: %d / %d' % (name, np.sum(batch_label == pred), batch_size))

plt.figure(figsize=(15, 15))
for i, (image, y) in enumerate(zip(batch_image, batch_label)):
  y_base = batch_pred['base'][i]
  y_adv = batch_pred['adv-regularized'][i]
  plt.subplot(n_row, n_col, i+1)
  plt.tight_layout()
  plt.title('true: %s, \n base: %s, \n adv: %s' % (label_map.get(tf.argmax(y, axis=-1).numpy()), label_map.get(y_base), label_map.get(y_adv)),fontsize=10)
  plt.imshow(tf.keras.preprocessing.image.array_to_img(image), cmap='gray')
  plt.axis('off')

plt.show()
# Out:
# accuracy in batch 0:
# base model: 0 / 50
# adv-regularized model: 0 / 50
# <ipython-input-68-b3cc83c7966a>:12: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   print('%s model: %d / %d' % (name, np.sum(batch_label == pred), batch_size))
# <ipython-input-68-b3cc83c7966a>:18: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(n_row, n_col, i+1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true_idx, predicted_idx)
# Out:
# 0.86
